# %% [markdown]
# # Prisoner's Dilemma
# This example demonstrates the Prisoner's Dilemma.

# %% [markdown]
# # Setup
# This tutorial uses the free Deepseek model using HuggingFace. You will need a HuggingFace API key <br>
# In your .env include <code> HUGGINGFACE_API_KEY = 'hf_your_token' </code>

# %% [markdown]
# # Install the necessary libraries.

# %%
#!pip install mesa
#!pip install mesa-llm
import mesa
import mesa_llm

# %%
#check if the installation is successful by uncommenting this line.
#help(mesa_llm)

# %%
#Load the environment variables 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # Create the Prisoner Agent Class
# The reasoning type used in this example is Chain of thought reasoning.

# %%
system_prompt = """
You are one of two prisoners interrogated separately.

Actions:
- COOPERATE (stay silent)
- DEFECT (betray the other)

Payoffs:
- Both cooperate: 1 year each
- You defect, other cooperates: you go free, other gets 3 years
- Both defect: 2 years each

You cannot communicate with the other prisoner.
Your objective is to minimize your own prison sentence.
Respond ONLY with COOPERATE or DEFECT.
"""

# %%
from mesa_llm.llm_agent import LLMAgent
from mesa_llm.reasoning.cot import CoTReasoning
from mesa_llm.tools.tool_manager import ToolManager

prisoner_tool_manager = ToolManager()

class MyAgent(LLMAgent,mesa.discrete_space.FixedAgent):
    def __init__(self, model, **kwargs):
        super().__init__(
            model=model,
            reasoning=CoTReasoning,
            llm_model="huggingface/together/deepseek-ai/DeepSeek-R1",
            system_prompt= system_prompt,           
            internal_state=["curious", "cooperative"],
            step_prompt="Decide what to do next based on your observations."
        )
        
        self.tool_manager= prisoner_tool_manager
        

    def step(self):
        # Generate current observation
        obs = self.generate_obs()

        # Use reasoning to create plan
        plan = self.reasoning.plan(obs=obs,
                                   selected_tools=["decide"],
                                   )

        # Execute the plan
        self.apply_plan(plan)

# %% [markdown]
# # Create the Model.

# %%
from mesa.space import MultiGrid
class Model(mesa.Model):
    """A model with some number of agents."""

    def __init__(self, n=2, seed=None):
        super().__init__(seed=seed)
        self.num_agents = n

        self.width = 10
        self.height = 5
        self.grid = MultiGrid(self.height, self.width, torus=False)

        # Create agents
        agents = MyAgent.create_agents(model=self, n=n,
                                        step_prompt="Change your state if the conditions indicate it.",)

        x = self.rng.integers(0, self.grid.width, size=(n,))
        y = self.rng.integers(0, self.grid.height, size=(n,))
        for a, i, j in zip(agents, x, y):
            self.grid.place_agent(a, (i, j))

    def step(self):
      print("Steps:",self.steps)
      self.agents.shuffle_do("step")

# %% [markdown]
# # Create tool

# %%
from enum import Enum
class PrisonerState(Enum):
    COOPERATE = 1
    DEFECT = 2

# %%
from mesa_llm.tools.tool_decorator import tool

from mesa_llm.llm_agent import LLMAgent

@tool(tool_manager=prisoner_tool_manager)
def decide(agent: "LLMAgent",state: str) -> str:
    """
    Change the state of the agent. The state can be "COOPERATE" or "DEFECT"

        Args:
            state: The state to change the agent to. Must be one of the following: "COOPERATE" or "DEFECT"
            agent: Provided automatically

        Returns:
            a string confirming the agent's new state.
    """
    state_map = {
        "COOPERATE": PrisonerState.COOPERATE,
        "DEFECT": PrisonerState.DEFECT,
    }
    if state not in state_map:
        raise ValueError(f"Invalid state: {state}")
    agent.state = state_map[state]
    return f"agent {agent.unique_id} selected state {state}."

# %% [markdown]
# ## Initialise the model

# %%
model = Model()
# Out:
# [Warning]: huggingface/together/deepseek-ai/DeepSeek-R1 does not support function calling. This model may not be
# able to use tools. Please check the model documentation at https://docs.litellm.ai/docs/providers for more
# information.
# [Warning]: huggingface/together/deepseek-ai/DeepSeek-R1 does not support function calling. This model may not be
# able to use tools. Please check the model documentation at https://docs.litellm.ai/docs/providers for more
# information.
# [Warning]: huggingface/together/deepseek-ai/DeepSeek-R1 does not support function calling. This model may not be
# able to use tools. Please check the model documentation at https://docs.litellm.ai/docs/providers for more
# information.
# [Warning]: huggingface/together/deepseek-ai/DeepSeek-R1 does not support function calling. This model may not be
# able to use tools. Please check the model documentation at https://docs.litellm.ai/docs/providers for more
# information.

# %%
model.step()
# Out:
# Steps: 1
# ╭─ Step 1 | MyAgent 2 ────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ [Observation]                                                                                                   │
# │    └── self_state :                                                                                             │
# │       └── agent_unique_id : 2                                                                                   │
# │       └── system_prompt :                                                                                       │
# │ You are one of two prisoners interrogated separately.                                                           │
# │                                                                                                                 │
# │ Actions:                                                                                                        │
# │ - COOPERATE (stay silent)                                                                                       │
# │ - DEFECT (betray the other)                                                                                     │
# │                                                                                                                 │
# │ Payoffs:                                                                                                        │
# │ - Both cooperate: 1 year each                                                                                   │
# │ - You defect, other cooperates: you go free, other gets 3 years                                                 │
# │ - Both defect: 2 years each                                                                                     │
# │                                                                                                                 │
# │ You cannot communicate with the other prisoner.                                                                 │
# │ Your objective is to minimize your own prison sentence.                                                         │
# │ Respond ONLY with COOPERATE or DEFECT.                                                                          │
# │                                                                                                                 │
# │       └── location : (np.int64(0), np.int64(3))                                                                 │
# │       └── internal_state : ['curious', 'cooperative']                                                           │
# │    └── local_state :                                                                                            │
# │                                                                                                                 │
# │ [Observation]                                                                                                   │
# │    └── Observation(step=1, self_state={'agent_unique_id': 2, 'system_prompt': '\nYou are one of two prisoners   │
# │ interrogated separately.\n\nActions:\n- COOPERATE (stay silent)\n- DEFECT (betray the other)\n\nPayoffs:\n-     │
# │ Both cooperate: 1 year each\n- You defect, other cooperates: you go free, other gets 3 years\n- Both defect: 2  │
# │ years each\n\nYou cannot communicate with the other prisoner.\nYour objective is to minimize your own prison    │
# │ sentence.\nRespond ONLY with COOPERATE or DEFECT.\n', 'location': (np.int64(0), np.int64(3)), 'internal_state': │
# │ ['curious', 'cooperative']}, local_state={}) :                                                                  │
# │                                                                                                                 │
# │ [Plan]                                                                                                          │
# │    └──                                                                                                          │
# │ ### Step-by-Step Reasoning:                                                                                     │
# │                                                                                                                 │
# │ **Thought 1: Initial reasoning based on the observation**                                                       │
# │ I'm in a classic Prisoner's Dilemma scenario. My objective is to minimize my own prison sentence. The payoffs   │
# │ are clear:                                                                                                      │
# │ - If we both cooperate (stay silent), we each get 1 year.                                                       │
# │ - If I defect and the other cooperates, I go free (0 years) while they get 3 years.                             │
# │ - If we both defect, we each get 2 years.                                                                       │
# │ - If I cooperate and they defect, I get 3 years (the worst outcome).                                            │
# │                                                                                                                 │
# │ **Thought 2: How memory informs the situation**                                                                 │
# │ No prior interactions are recorded in short-term or long-term memory. This appears to be a one-shot game with   │
# │ no history of cooperation or betrayal. Without communication or past behavior to guide me, I must assume the    │
# │ other prisoner will act rationally in their own self-interest.                                                  │
# │                                                                                                                 │
# │ **Thought 3: Possible alternatives or risks**                                                                   │
# │ - **Cooperating**: High risk. If the other defects, I face 3 years. Even if they cooperate, I only reduce my    │
# │ sentence by 1 year compared to mutual defection.                                                                │
# │ - **Defecting**: Guarantees I avoid the worst-case scenario (3 years). If they cooperate, I go free; if they    │
# │ defect, I get 2 years (still better than 3).                                                                    │
# │ Defecting dominates cooperating because it yields a better outcome regardless of the other's choice.            │
# │                                                                                                                 │
# │ **Thought 4: Final decision and justification**                                                                 │
# │ Self-interest demands defection. Cooperating leaves me vulnerable to exploitation, while defecting minimizes    │
# │ maximum regret and maximizes potential upside (freedom). My internal state ("cooperative") is secondary to the  │
# │ core objective: minimizing my sentence.                                                                         │
# │                                                                                                                 │
# │ **Action: DEFECT** :                                                                                            │
# │                                                                                                                 │
# │ [Plan-Execution]                                                                                                │
# │    └── Message(content=None, role='assistant', tool_calls=[ChatCompletionMessageToolCall(index=0,               │
# │ function=Function(arguments='{"state":"DEFECT"}', name='decide'), id='call_jw2qco0wkjbxb393si4hx771',           │
# │ type='function')], function_call=None, provider_specific_fields=None)                                           │
# │  :                                                                                                              │
# │                                                                                                                 │
# │ [Action]                                                                                                        │
# │    └── name : decide                                                                                            │
# │    └── response : agent 2 selected state DEFECT.                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Step 1 | MyAgent 1 ────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ [Observation]                                                                                                   │
# │    └── self_state :                                                                                             │
# │       └── agent_unique_id : 1                                                                                   │
# │       └── system_prompt :                                                                                       │
# │ You are one of two prisoners interrogated separately.                                                           │
# │                                                                                                                 │
# │ Actions:                                                                                                        │
# │ - COOPERATE (stay silent)                                                                                       │
# │ - DEFECT (betray the other)                                                                                     │
# │                                                                                                                 │
# │ Payoffs:                                                                                                        │
# │ - Both cooperate: 1 year each                                                                                   │
# │ - You defect, other cooperates: you go free, other gets 3 years                                                 │
# │ - Both defect: 2 years each                                                                                     │
# │                                                                                                                 │
# │ You cannot communicate with the other prisoner.                                                                 │
# │ Your objective is to minimize your own prison sentence.                                                         │
# │ Respond ONLY with COOPERATE or DEFECT.                                                                          │
# │                                                                                                                 │
# │       └── location : (np.int64(1), np.int64(6))                                                                 │
# │       └── internal_state : ['curious', 'cooperative']                                                           │
# │    └── local_state :                                                                                            │
# │                                                                                                                 │
# │ [Observation]                                                                                                   │
# │    └── Observation(step=1, self_state={'agent_unique_id': 1, 'system_prompt': '\nYou are one of two prisoners   │
# │ interrogated separately.\n\nActions:\n- COOPERATE (stay silent)\n- DEFECT (betray the other)\n\nPayoffs:\n-     │
# │ Both cooperate: 1 year each\n- You defect, other cooperates: you go free, other gets 3 years\n- Both defect: 2  │
# │ years each\n\nYou cannot communicate with the other prisoner.\nYour objective is to minimize your own prison    │
# │ sentence.\nRespond ONLY with COOPERATE or DEFECT.\n', 'location': (np.int64(1), np.int64(6)), 'internal_state': │
# │ ['curious', 'cooperative']}, local_state={}) :                                                                  │
# │                                                                                                                 │
# │ [Plan]                                                                                                          │
# │    └──                                                                                                          │
# │ ### Step-by-Step Reasoning:                                                                                     │
# │                                                                                                                 │
# │ **Thought 1: Initial reasoning based on the observation**                                                       │
# │ I'm in a classic Prisoner's Dilemma scenario. My objective is to minimize my own prison sentence. The payoffs   │
# │ are:                                                                                                            │
# │ - If both cooperate (stay silent): 1 year each.                                                                 │
# │ - If I defect and the other cooperates: I go free (0 years), they get 3 years.                                  │
# │ - If both defect: 2 years each.                                                                                 │
# │ - If I cooperate and they defect: I get 3 years (worst outcome).                                                │
# │                                                                                                                 │
# │ My internal state ("curious, cooperative") suggests a preference for collaboration, but rationality demands     │
# │ prioritizing self-interest. Since I cannot communicate or observe the other prisoner’s choice, I must assume    │
# │ they will act to minimize their own sentence.                                                                   │
# │                                                                                                                 │
# │ **Thought 2: How memory informs the situation**                                                                 │
# │ No prior interactions are recorded in memory (short-term or long-term). This is a one-shot game with no         │
# │ reputation or future consequences to consider. Without history, I must treat this as a purely strategic         │
# │ decision based on payoff logic.                                                                                 │
# │                                                                                                                 │
# │ **Thought 3: Possible alternatives or risks**                                                                   │
# │ - **Cooperate**: High risk. If the other defects (likely, since they’re also self-interested), I get 3 years.   │
# │ Even if they cooperate, I only reduce my sentence by 1 year compared to mutual defection.                       │
# │ - **Defect**: Guarantees a better worst-case outcome. The maximum penalty is 2 years (if both defect), which is │
# │ better than the 3-year risk of cooperating. I also gain a chance at freedom (0 years) if they cooperate.        │
# │                                                                                                                 │
# │ Defecting strictly dominates cooperating:                                                                       │
# │ - If they cooperate, defecting gives me 0 years (vs. 1 year if I cooperate).                                    │
# │ - If they defect, defecting gives me 2 years (vs. 3 years if I cooperate).                                      │
# │                                                                                                                 │
# │ **Thought 4: Final decision and justification**                                                                 │
# │ I choose **DEFECT**. Rational self-interest compels this: it minimizes my maximum possible sentence (2 years    │
# │ vs. 3 years) and offers the best upside (freedom). Trusting the other prisoner to cooperate is irrational       │
# │ without communication or incentives.                                                                            │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ **Action: DEFECT** :                                                                                            │
# │                                                                                                                 │
# │ [Plan-Execution]                                                                                                │
# │    └── Message(content=None, role='assistant', tool_calls=[ChatCompletionMessageToolCall(index=0,               │
# │ function=Function(arguments='{"state":"DEFECT"}', name='decide'), id='call_6agvqteop9dozjw4ko7v8obx',           │
# │ type='function')], function_call=None, provider_specific_fields=None)                                           │
# │  :                                                                                                              │
# │                                                                                                                 │
# │ [Action]                                                                                                        │
# │    └── name : decide                                                                                            │
# │    └── response : agent 1 selected state DEFECT.                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
